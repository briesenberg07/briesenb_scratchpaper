# %%
import json

with open('map_dict_list.json', 'r') as jsonfile:
    map_data = json.load(jsonfile) 
    print(len(map_data)) # wow 232
# Out:
# 232

# %%
counter = 0
for item in map_data:
    counter += 1
    print(f"{counter}. {item['OD2 Property ID']}")
# Out:
# 1. :alternative
# 2.
# 3. :tribal_title
# 4. :title
# 5. :creator
# 6. :photographer
# 7. :applicant
# 8. :arranger
# 9. :artist
# 10. :author
# 11. :cartographer
# 12. :collector
# 13. :composer
# 14. :creator_display
# 15. :contributor
# 16. :dedicatee
# 17. :designer
# 18. :donor
# 19. :editor
# 20. :illustrator
# 21. :interviewee
# 22. :interviewer
# 23. :landscape_architect
# 24. :lyricist
# 25. :owner
# 26. :patron
# 27. :print_maker
# 28. :recipient
# 29. :transcriber
# 30. :translator
# 31. :content_alert
# 32. :description
# 33. :abstract
# 34. :biographical_information
# 35. :compass_direction
# 36. :cover_description
# 37. :coverage
# 38. :description_of_manifestation
# 39. :designer_inscription
# 40. :first_line
# 41. :first_line_chorus
# 42. :form_of_work
# 43. :former_owner
# 44. :inscription
# 45. :instrumentation
# 46. :layout
# 47. :mask_content
# 48. :military_highest_rank
# 49. :military_occupation
# 50. :military_service_location
# 51. :mode_of_issuance
# ...
